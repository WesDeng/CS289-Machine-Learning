# %%
# Learning rate: 0.001, hidden layer size: 10, final test acc: 0.877
plot_loss(train, val, 0.001, 10)

# %%
# Learning rate: 0.01, hidden layer size: 20, final test acc: 0.933
plot_loss(train, val, 0.01, 20)

# %%
# Learning rate: 0.05, hidden layer size: 50, final test acc: 0.933
plot_loss(train, val, 0.05, 50)

# %%
# Learning rate: 0.001, hidden layer size: 30, final test acc: 0.866
plot_loss(train, val, 0.001, 30)
